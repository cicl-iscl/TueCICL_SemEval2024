# %%
from loader.uar import UAR
from loader.data import TaskA_Dataset

# %%
uar = UAR()
dataset = TaskA_Dataset(split="train")
# Out:
# <class 'transformers_modules.rrivera1849.LUAR-MUD.6bbc5d9bd99209d2e63604f18e60e519838f74c5.model.LUAR'>

# %%
from tqdm import tqdm


vectors = {}

for i in tqdm(range(len(dataset))):
    text, label, _id = dataset[i]
    vec = uar.get([text])
    vec = vec[0]
    vectors[_id] = vec
# Out:
#   0%|          | 336/119757 [18:03<106:56:11,  3.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 8
#       6 for i in tqdm(range(len(dataset))):
#       7     text, label, _id = dataset[i]
# ----> 8     vec = uar.get([text])
#       9     vec = vec[0]
#      10     vectors[_id] = vec
#
# File ~/cicl/taskA/src/loader/uar.py:37, in UAR.get(self, texts)
#      36 def get(self, texts: List[str]):
# ---> 37     tensors = [self._get(text) for text in texts]
#      38     return torch.stack(tensors, dim=0)
#
# File ~/cicl/taskA/src/loader/uar.py:37, in <listcomp>(.0)
#      36 def get(self, texts: List[str]):
# ---> 37     tensors = [self._get(text) for text in texts]
#      38     return torch.stack(tensors, dim=0)
#
# File ~/cicl/taskA/src/loader/uar.py:33, in UAR._get(self, text)
# ...
